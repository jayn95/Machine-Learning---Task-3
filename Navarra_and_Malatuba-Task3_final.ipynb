# %% [markdown]
# # Task 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
plt.style.use
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <function matplotlib.style.core.use(style)>

# %% [markdown]
# ## Data Info/Summary
#  - What are the columns/feature present in the dataset?
#  - What are their data types?
#  - Provide statistics of the dataset

# %%
df = pd.read_csv('bank.csv')
print(f"Shape of dataframe: {df.shape}")
df
# Out:
# Shape of dataframe: (11162, 17)
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %% [markdown]
# ## Data Preprocessing
#  - Check for duplicate and missing values
#  - Remove jobs with "unknown" values
#  - Convert "admin" from [job] column to "management" since they are just the same

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11157    False
# 11158    False
# 11159    False
# 11160    False
# 11161    False
# Length: 11162, dtype: bool

# %%
df.isnull().count()
# Out:
# age          11162
# job          11162
# marital      11162
# education    11162
# default      11162
# balance      11162
# housing      11162
# loan         11162
# contact      11162
# day          11162
# month        11162
# duration     11162
# campaign     11162
# pdays        11162
# previous     11162
# poutcome     11162
# deposit      11162
# dtype: int64

# %%
df['job'].isnull().to_frame('NaN Value').T
# Out:
#            0      1      2      3      4      5      6      7      8      \
# NaN Value  False  False  False  False  False  False  False  False  False
#
#            9      ...  11152  11153  11154  11155  11156  11157  11158  11159  \
# NaN Value  False  ...  False  False  False  False  False  False  False  False
#
#            11160  11161
# NaN Value  False  False
#
# [1 rows x 11162 columns]

# %%
# dropping jobs with unknown value
df.dropna(subset=['job'])
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df.loc[df['job']== 'admin.', 'job'] = 'management'
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59   management  married  secondary      no     2343     yes   no
# 1       56   management  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54   management  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
correlation = df.drop(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'deposit'], axis=1)
correlation.corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.112300 -0.000762  0.000189 -0.005278  0.002774  0.020169
# balance   0.112300  1.000000  0.010467  0.022436 -0.013894  0.017411  0.030805
# day      -0.000762  0.010467  1.000000 -0.018511  0.137007 -0.077232 -0.058981
# duration  0.000189  0.022436 -0.018511  1.000000 -0.041557 -0.027392 -0.026716
# campaign -0.005278 -0.013894  0.137007 -0.041557  1.000000 -0.102726 -0.049699
# pdays     0.002774  0.017411 -0.077232 -0.027392 -0.102726  1.000000  0.507272
# previous  0.020169  0.030805 -0.058981 -0.026716 -0.049699  0.507272  1.000000

# %% [markdown]
# ## Data Visualization
# (provide short discussion for each)
#  - Correlation Matrix
#  - Univariate analyis using KDE Graph
#  - Bivariate analysis using Scatterplot (just choose one)
#    - Balance vs Occupation

# %%
font = {'fontsize':16, 'fontstyle': 'italic', 'backgroundcolor':'darkblue', 'color':'white'}
sns.heatmap(correlation.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There's a bug on seaborn package

# %% [markdown]
# Univariate analysis using KDE Graph

# %%
font = {'fontsize':16, 'fontstyle': 'italic', 'backgroundcolor':'darkblue', 'color':'white'}
# %matplotlib inline
sns.kdeplot(df['age'], shade=True)
plt.title('KDE Plot of {}'.format('age'))
plt.xlabel('Values')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ## Balance vs. Occupation
# ## Loans vs. Education

# %%
# %matplotlib inline
sns.scatterplot(data=df, x='balance', y='job')
plt.title('Scatter plot of Balance vs Occupation', y=1.04, fontdict=font)
plt.xlabel('Balance')
plt.ylabel('Occupation')
plt.show()

# %% [markdown]
# The plot showed that most of the jobs had a balance of lesser than 20,000. The plot also shows the highest amount of balance in each job.

# %% [markdown]
# ## Train a Naive Bayes Classifier
#  - Provide model performance

# %%
import category_encoders as ce
from sklearn.preprocessing import RobustScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix


# Encoding categorical variables
encoder = ce.OneHotEncoder(cols=['job','marital','education','default','housing','contact','month',
                                 'poutcome','deposit'])
x_train_encoded = encoder.fit_transform(x_train)
x_test_encoded = encoder.transform(x_test)

# Scaling the features
scaler = RobustScaler()
x_train_scaled = scaler.fit_transform(x_train_encoded)
x_test_scaled = scaler.transform(x_test_encoded)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# Create and fit the Gaussian Naive Bayes model
gnb = GaussianNB()
gnb.fit(x_train_scaled, y_train)

# Predict the results
y_pred = gnb.predict(x_test_scaled)

print("True values: ", (y_pred == 'yes').sum())
print("False values: ", (y_pred == 'no').sum())
# Out:
# True values:  2427
# False values:  922

# %%
print(f"x_train: {x_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"x_test: {x_test.shape}")
print(f"y_test: {y_test.shape}")

TP = cm[0,0]
TN = cm[1,1]
FP = cm[0,1]
FN = cm[1,0]
# Out:
# x_train: (7813, 16)
# y_train: (7813,)
# x_test: (3349, 16)
# y_test: (3349,)

# %%
null_accuracy = (7407/(7407+2362))
precision = TP / float(TP + FP)
recall = TP / float(TP + FN)
f1_score = 2 * (precision * recall) / (precision + recall)

print('Model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
print('Null accuracy score: {0:0.4f}'. format(null_accuracy))
print('Precision : {0:0.4f}'.format(precision))
print('Recall : {0:0.4f}'.format(recall))
print('F1 Score : {0:0.4f}'.format(f1_score))

cm = confusion_matrix(y_test, y_pred)
print('Confusion matrix\n', cm)

# seaborn heatmap for the confusion matrix
cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], 
                                 index=['Predict Positive:1', 'Predict Negative:0'])
sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# Model accuracy score: 0.3774
# Null accuracy score: 0.7582
# Precision : 0.3004
# Recall : 0.9490
# F1 Score : 0.4563
# Confusion matrix
#  [[ 875 2038]
#  [  47  389]]
# <AxesSubplot:>
